# %%
#import required libraries
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from datetime import datetime
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
# Out:
# /home/ishadi/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# concatanating the date and the time stamp into one column

# %%
# import csv
# with open('concat.csv') as f:
#     reader = csv.reader(f)
#     with open('output.csv', 'w') as g:
#         writer = csv.writer(g)
#         for row in reader:
#             new_row = [' '.join([row[0], row[1]])] + row[2:]
#             writer.writerow(new_row)

# %%
# load data
def parse(x):
	return datetime.strptime(x, '%Y.%m.%d %H:%M')
dataset = read_csv('concat.csv', date_parser=parse)
#dataset = read_csv('output.csv')
#dataset.drop('No', axis=1, inplace=True)

# manually specify column names
dataset.columns = ['Date time stamp', 'Bar OPEN Bid Quote', 'Bar HIGH Bid Quote', 'Bar LOW Bid Quote', 'Bar CLOSE Bid Quote', 'Volume']
dataset.index.name = 'Date time stamp'

# mark all NA values with 0
dataset['Bar OPEN Bid Quote'].fillna(0, inplace=True)
# drop the first 24 hours
#dataset = dataset[24:]

#dataset.shape()

# summarize first 5 rows
print(dataset.head(5))
print(dataset.tail(5))

# save to file
dataset.to_csv('2016.csv')
# Out:
#                   Date time stamp  Bar OPEN Bid Quote  Bar HIGH Bid Quote  \
# Date time stamp
# 0                2016.01.03 17:01             1.08712             1.08712
# 1                2016.01.03 17:02             1.08708             1.08722
# 2                2016.01.03 17:03             1.08717             1.08723
# 3                2016.01.03 17:04             1.08718             1.08718
# 4                2016.01.03 17:05             1.08703             1.08716
#
#                  Bar LOW Bid Quote  Bar CLOSE Bid Quote  Volume
# Date time stamp
# 0                          1.08712              1.08712       0
# 1                          1.08708              1.08722       0
# 2                          1.08717              1.08723       0
# 3                          1.08711              1.08711       0
# 4                          1.08701              1.08712       0
#                   Date time stamp  Bar OPEN Bid Quote  Bar HIGH Bid Quote  \
# Date time stamp
# 744308           2017.12.29 16:53             1.19972             1.19987
# 744309           2017.12.29 16:54             1.19985             1.19985
# 744310           2017.12.29 16:55             1.19969             1.20014
# 744311           2017.12.29 16:56             1.20009             1.20023
# 744312           2017.12.29 16:57             1.19982             1.20074
#
#                  Bar LOW Bid Quote  Bar CLOSE Bid Quote  Volume
# Date time stamp
# 744308                     1.19972              1.19987       0
# 744309                     1.19970              1.19970       0
# 744310                     1.19961              1.20010       0
# 744311                     1.19974              1.19983       0
# 744312                     1.19980              1.20005       0

# %%
#Loads the new “2016.csv” file and plots each series as a separate subplot

# %%
# # load dataset
# dataset = read_csv('2016.csv', header=0, index_col=0)
# values = dataset.values

# # specify columns to plot
# groups = [0, 1, 2, 3, 4, 5]
# i = 1

# # plot each column
# pyplot.figure()
# for group in groups:
# 	pyplot.subplot(len(groups), 1, i)
# 	pyplot.plot(values[:, group])
# 	pyplot.title(dataset.columns[group], y=0.5, loc='right')
# 	i += 1
# pyplot.show()

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg
 
# load dataset
dataset = read_csv('2016.csv', header=0, index_col=0)
values = dataset.values

# integer encode direction
encoder = LabelEncoder()
values[:,0] = encoder.fit_transform(values[:,0])

# ensure all data is float
values = values.astype('float32')

# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)

# drop columns we don't want to predict
reframed.drop(reframed.columns[[7,8,9,10,11]], axis=1, inplace=True)
print(reframed.head())
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)   var1(t)
# 1   0.000000   0.301724   0.300962   0.303582   0.302078        0.0  0.000001
# 2   0.000001   0.301495   0.301534   0.303353   0.302650        0.0  0.000003
# 3   0.000003   0.302010   0.301592   0.303868   0.302707        0.0  0.000004
# 4   0.000004   0.302067   0.301306   0.303525   0.302021        0.0  0.000005
# 5   0.000005   0.301208   0.301191   0.302953   0.302078        0.0  0.000007

# %%
#LSTM with 50 neurons in the first hidden layer 
#1 neuron in the output layer for predicting foreign currency rate
#The input shape will be 1 time step with 6 features.

# %%
# split into train and test sets# 
values = reframed.values
n_train_minutes = 255 * 24 * 60 * 2
train = values[:n_train_minutes, :]
test = values[n_train_minutes:, :]

# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (734400, 1, 6) (734400,) (9912, 1, 6) (9912,)

# %%
#The model will be fit for 50 training epochs with a batch size of 72

# %%
#design network# 
# model = Sequential()
# model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
# model.add(Dense(6, activation='relu'))
# model.add(Dense(6, activation='relu'))
# #output layer
# model.add(Dense(1, activation='linear'))
# # efficient gradient descent algorithm - adam
# model.compile(loss='mae', optimizer='adam')


model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(LSTM(6))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')


# model = Sequential()
# model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
# model.add(Dense(1))
# model.compile(loss='mae', optimizer='adam')

# fit network
# batch size-number of instances that are evaluated before a weight update in the network is performed
history = model.fit(train_X, train_y, epochs=100, batch_size=150, validation_data=(test_X, test_y), verbose=2, shuffle=False)

# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Train on 734400 samples, validate on 9912 samples
# Epoch 1/100
#  - 8s - loss: 0.0062 - val_loss: 0.0116
# Epoch 2/100
#  - 8s - loss: 0.0068 - val_loss: 0.0024
# Epoch 3/100
#  - 8s - loss: 0.0060 - val_loss: 0.0022
# Epoch 4/100
#  - 8s - loss: 0.0051 - val_loss: 0.0044
# Epoch 5/100
#  - 8s - loss: 0.0043 - val_loss: 0.0073
# Epoch 6/100
#  - 8s - loss: 0.0035 - val_loss: 0.0020
# Epoch 7/100
#  - 8s - loss: 0.0033 - val_loss: 0.0022
# Epoch 8/100
#  - 8s - loss: 0.0027 - val_loss: 0.0030
# Epoch 9/100
#  - 8s - loss: 0.0024 - val_loss: 0.0050
# Epoch 10/100
#  - 8s - loss: 0.0022 - val_loss: 0.0049
# Epoch 11/100
#  - 8s - loss: 0.0020 - val_loss: 7.3747e-04
# Epoch 12/100
#  - 8s - loss: 0.0020 - val_loss: 0.0041
# Epoch 13/100
#  - 8s - loss: 0.0019 - val_loss: 0.0018
# Epoch 14/100
#  - 8s - loss: 0.0018 - val_loss: 0.0044
# Epoch 15/100
#  - 8s - loss: 0.0019 - val_loss: 9.3319e-04
# Epoch 16/100
#  - 8s - loss: 0.0020 - val_loss: 0.0017
# Epoch 17/100
#  - 8s - loss: 0.0017 - val_loss: 0.0059
# Epoch 18/100
#  - 8s - loss: 0.0016 - val_loss: 0.0048
# Epoch 19/100
#  - 8s - loss: 0.0017 - val_loss: 0.0021
# Epoch 20/100
#  - 8s - loss: 0.0017 - val_loss: 0.0014
# Epoch 21/100
#  - 8s - loss: 0.0017 - val_loss: 0.0017
# Epoch 22/100
#  - 9s - loss: 0.0017 - val_loss: 6.6319e-04
# Epoch 23/100
#  - 8s - loss: 0.0017 - val_loss: 0.0033
# Epoch 24/100
#  - 8s - loss: 0.0017 - val_loss: 0.0020
# Epoch 25/100
#  - 8s - loss: 0.0015 - val_loss: 8.7563e-04
# Epoch 26/100
#  - 9s - loss: 0.0015 - val_loss: 0.0019
# Epoch 27/100
#  - 8s - loss: 0.0015 - val_loss: 9.7800e-04
# Epoch 28/100
#  - 9s - loss: 0.0015 - val_loss: 0.0018
# Epoch 29/100
#  - 8s - loss: 0.0015 - val_loss: 0.0031
# Epoch 30/100
#  - 8s - loss: 0.0014 - val_loss: 0.0015
# Epoch 31/100
#  - 8s - loss: 0.0014 - val_loss: 0.0038
# Epoch 32/100
#  - 8s - loss: 0.0014 - val_loss: 0.0013
# Epoch 33/100
#  - 8s - loss: 0.0014 - val_loss: 0.0016
# Epoch 34/100
#  - 8s - loss: 0.0013 - val_loss: 8.0519e-04
# Epoch 35/100
#  - 8s - loss: 0.0012 - val_loss: 0.0039
# Epoch 36/100
#  - 8s - loss: 0.0012 - val_loss: 0.0054
# Epoch 37/100
#  - 8s - loss: 0.0012 - val_loss: 0.0010
# Epoch 38/100
#  - 8s - loss: 0.0013 - val_loss: 8.6499e-04
# Epoch 39/100
#  - 8s - loss: 0.0013 - val_loss: 0.0028
# Epoch 40/100
#  - 8s - loss: 0.0011 - val_loss: 0.0011
# Epoch 41/100
#  - 8s - loss: 0.0011 - val_loss: 9.0531e-04
# Epoch 42/100
#  - 8s - loss: 0.0011 - val_loss: 0.0042
# Epoch 43/100
#  - 8s - loss: 0.0012 - val_loss: 8.8499e-04
# Epoch 44/100
#  - 8s - loss: 0.0010 - val_loss: 0.0019
# Epoch 45/100
#  - 8s - loss: 0.0012 - val_loss: 0.0014
# Epoch 46/100
#  - 8s - loss: 0.0011 - val_loss: 0.0015
# Epoch 47/100
#  - 8s - loss: 0.0013 - val_loss: 0.0014
# Epoch 48/100
#  - 8s - loss: 0.0012 - val_loss: 0.0013
# Epoch 49/100
#  - 8s - loss: 0.0012 - val_loss: 0.0029
# Epoch 50/100
#  - 8s - loss: 0.0011 - val_loss: 0.0040
# Epoch 51/100
#  - 8s - loss: 0.0011 - val_loss: 0.0012
# Epoch 52/100
#  - 8s - loss: 0.0012 - val_loss: 9.6291e-04
# Epoch 53/100
#  - 8s - loss: 0.0011 - val_loss: 0.0034
# Epoch 54/100
#  - 8s - loss: 0.0011 - val_loss: 0.0011
# Epoch 55/100
#  - 8s - loss: 0.0011 - val_loss: 0.0027
# Epoch 56/100
#  - 8s - loss: 0.0010 - val_loss: 9.5345e-04
# Epoch 57/100
#  - 8s - loss: 0.0010 - val_loss: 9.7628e-04
# Epoch 58/100
#  - 8s - loss: 0.0010 - val_loss: 0.0012
# Epoch 59/100
#  - 8s - loss: 0.0010 - val_loss: 0.0012
# Epoch 60/100
#  - 8s - loss: 0.0011 - val_loss: 9.9895e-04
# Epoch 61/100
#  - 8s - loss: 0.0010 - val_loss: 0.0019
# Epoch 62/100
#  - 8s - loss: 0.0011 - val_loss: 0.0016
# Epoch 63/100
#  - 8s - loss: 0.0010 - val_loss: 0.0053
# Epoch 64/100
#  - 8s - loss: 0.0011 - val_loss: 0.0015
# Epoch 65/100
#  - 9s - loss: 9.6053e-04 - val_loss: 0.0014
# Epoch 66/100
#  - 10s - loss: 9.9613e-04 - val_loss: 0.0021
# Epoch 67/100
#  - 11s - loss: 9.6467e-04 - val_loss: 0.0019
# Epoch 68/100
#  - 10s - loss: 0.0010 - val_loss: 0.0018
# Epoch 69/100
#  - 9s - loss: 0.0011 - val_loss: 0.0011
# Epoch 70/100
#  - 9s - loss: 0.0010 - val_loss: 0.0019
# Epoch 71/100
#  - 8s - loss: 9.8805e-04 - val_loss: 9.4492e-04
# Epoch 72/100
#  - 8s - loss: 0.0010 - val_loss: 9.9367e-04
# Epoch 73/100
#  - 8s - loss: 0.0011 - val_loss: 0.0033
# Epoch 74/100
#  - 9s - loss: 0.0010 - val_loss: 9.7758e-04
# Epoch 75/100
#  - 9s - loss: 9.8689e-04 - val_loss: 0.0034
# Epoch 76/100
#  - 9s - loss: 9.7088e-04 - val_loss: 0.0060
# Epoch 77/100
#  - 8s - loss: 0.0010 - val_loss: 0.0010
# Epoch 78/100
#  - 8s - loss: 0.0010 - val_loss: 0.0025
# Epoch 79/100
#  - 8s - loss: 0.0011 - val_loss: 0.0048
# Epoch 80/100
#  - 8s - loss: 0.0010 - val_loss: 0.0017
# Epoch 81/100
#  - 8s - loss: 9.5647e-04 - val_loss: 9.5070e-04
# Epoch 82/100
#  - 8s - loss: 0.0010 - val_loss: 0.0053
# Epoch 83/100
#  - 8s - loss: 0.0010 - val_loss: 0.0025
# Epoch 84/100
#  - 8s - loss: 9.8919e-04 - val_loss: 9.8163e-04
# Epoch 85/100
#  - 8s - loss: 9.3214e-04 - val_loss: 0.0041
# Epoch 86/100
#  - 8s - loss: 0.0010 - val_loss: 0.0028
# Epoch 87/100
#  - 9s - loss: 9.4758e-04 - val_loss: 9.2821e-04
# Epoch 88/100
#  - 9s - loss: 9.5484e-04 - val_loss: 9.8373e-04
# Epoch 89/100
#  - 10s - loss: 9.8841e-04 - val_loss: 0.0020
# Epoch 90/100
#  - 10s - loss: 9.9024e-04 - val_loss: 0.0018
# Epoch 91/100
#  - 9s - loss: 9.4239e-04 - val_loss: 0.0015
# Epoch 92/100
#  - 9s - loss: 9.6063e-04 - val_loss: 0.0021
# Epoch 93/100
#  - 9s - loss: 9.6600e-04 - val_loss: 9.1533e-04
# Epoch 94/100
#  - 8s - loss: 9.3080e-04 - val_loss: 0.0015
# Epoch 95/100
#  - 8s - loss: 9.3040e-04 - val_loss: 0.0010
# Epoch 96/100
#  - 9s - loss: 9.2894e-04 - val_loss: 9.4703e-04
# Epoch 97/100
#  - 9s - loss: 9.7515e-04 - val_loss: 0.0051
# Epoch 98/100
#  - 9s - loss: 9.5806e-04 - val_loss: 0.0028
# Epoch 99/100
#  - 8s - loss: 9.6209e-04 - val_loss: 0.0012
# Epoch 100/100
#  - 9s - loss: 0.0010 - val_loss: 0.0010

# %%
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 960.962

# %%
# # evaluate the model
# scores = model.evaluate(X, Y)
# print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-5dc5f702af30> in <module>()
#       1 # evaluate the model
# ----> 2 scores = model.evaluate(test_X, test_y)
#       3 # print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps)
#    1103             x, y,
#    1104             sample_weight=sample_weight,
# -> 1105             batch_size=batch_size)
#    1106         # Prepare inputs, delegate logic to `test_loop`.
#    1107         if self._uses_dynamic_learning_phase():
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     752             feed_input_shapes,
#     753             check_batch_axis=False,  # Don't enforce the batch size.
# --> 754             exception_prefix='input')
#     755
#     756         if y is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     124                         ': expected ' + names[i] + ' to have ' +
#     125                         str(len(shape)) + ' dimensions, but got array '
# --> 126                         'with shape ' + str(data_shape))
#     127                 if not check_batch_axis:
#     128                     data_shape = data_shape[1:]
#
# ValueError: Error when checking input: expected lstm_4_input to have 3 dimensions, but got array with shape (9912, 6)

# %%
# new instance where we do not know the answer
#Xnew = array([[0.29466096, 0.30317302]])

# %%
# make a prediction
#ynew = model.predict(Xnew)

# %%
# show the inputs and predicted outputs
#print("X=%s, Predicted=%s" % (Xnew[0], ynew[0]))
